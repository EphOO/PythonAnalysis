# %%
import pandas as pd

# %%
Dataset = pd.read_csv(r"C:\Users\HP\Downloads\7. Udemy Courses.csv")

# %%
Dataset.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
Dataset.tail()
# Out:
#       course_id                                       course_title  is_paid  \
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 3677   120             1566           29            36      All Levels
# 3678    70             1018           12            22  Beginner Level
# 3679    40              723          130            37      All Levels
# 3680  Free              229            0            33      All Levels
# 3681    50               12            1            15      All Levels
#
#      content_duration   published_timestamp              subject
# ...

# %%
#What are the different subjects for which udemy is offering courses?

Dataset.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
#What is the maximum number of courses for each subject

Dataset.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
#Show the all the free courses

Dataset[Dataset.is_paid==False]
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
#Show the all the paid courses

Dataset[Dataset.is_paid==True]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
# Which are the top selling courses

Dataset.sort_values('num_subscribers' , ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...     True
# 1267    1258666                Financial Statement Auditing Cycles     True
# 2070    1215926                Kickstarter success in 5 easy steps     True
# 1931    1247992  Introduction to Project Management for Finance...     True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...     True
#
# ...

# %%
# Which are the least selling courses

Dataset.sort_values('num_subscribers')
# Out:
#       course_id                                       course_title  is_paid  \
# 649     1233314                      Building a Balanced Scorecard     True
# 3259    1232282          The Cash Flow Statement - An Introduction     True
# 3261    1275872                    The Complete Adobe Spark Course     True
# 910      726314       Create Beautiful Image Maps for Your Website     True
# 3328     715476        The Cuckoo Strategy to get European Funding     True
# ...         ...                                                ...      ...
# 3316     764164              The Complete Web Developer Course 2.0     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3385     625204                         The Web Developer Bootcamp     True
# 776       59014                     Coding for Entrepreneurs Basic    False
# 2230      41295               Learn HTML5 Programming From Scratch    False
#
# ...

# %%
#Show all course of Web Development/ Business Finance where the price is >= 100

Dataset[(Dataset.subject == "Web Development") & (Dataset.price >= "100")]
# Out:
#       course_id                                       course_title  is_paid  \
# 11        64605                                         1 Hour CSS     True
# 12        64422                                        1 Hour HTML     True
# 13        63612                                  1 Hour JavaScript     True
# 14        72262                                      1 hour jQuery     True
# 24       975916  17 Complete JavaScript   projects explained st...     True
# ...         ...                                                ...      ...
# 3666     969170                          XSD :basics for beginners     True
# 3667     968278                         XSLT :basics for beginners     True
# 3670     560996  You can create Incredible Websites with HTML C...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
#show all courses List out all the courses that are related to Python

Dataset[Dataset.course_title.str.contains("Python")]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
#show all courses List out all the courses that are related to SQL

Dataset[Dataset.course_title.str.contains("SQL")]
# Out:
#       course_id                                       course_title  is_paid  \
# 56       304490  A 13 Hour SQL Server 2014 /ASP.NET/CSS/C#/jQue...     True
# 145      425084  Administering Microsoft SQL Server 2012 Databa...     True
# 273     1155262  Angular 2 Complete E-Commerce App Course - Jav...     True
# 585      992114  Build A Complete CRUD Application With PHP, MY...     True
# 653      155640            Building a Search Engine in PHP & MySQL    False
# 654      431576  Building a Social Network in PHP & MySQL From ...     True
# 799     1070976  Complete E-Commerce Course - Java,Spring,Hiber...     True
# 809      552198  Complete Login and Registration System in PHP ...     True
# 821       98066  Complete Website & CMS in PHP & MySQL From Scr...     True
# 892      418386  Create a REAL Social Network like Facebook in ...     True
# 1305     921560  For Free - Deploy Quickly Spring Boot on Herok...     True
# ...

# %%
#show all counts of courses that are related to Python

len(Dataset[Dataset.course_title.str.contains("Python")])
# Out:
# 29

# %%
#show all counts of courses that are related to SQL

len(Dataset[Dataset.course_title.str.contains("SQL")])
# Out:
# 24

# %%
Dataset.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
#What are courses published in the year 2015/2020/2023

#I had to change the datatype of 'published_timestamp'  from "object" to "datetime" before I can answer the above question.

Dataset["published_timestamp"] = pd.to_datetime(Dataset.published_timestamp)

# %%
Dataset['Year'] = Dataset['published_timestamp'].dt.year

# %%
Dataset
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
Dataset['Month'] = Dataset['published_timestamp'].dt.month

# %%
Dataset
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
Dataset['Day'] = Dataset['published_timestamp'].dt.day

# %%
Dataset
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
#What are courses published in the year 2014/2017/2020

Dataset[Dataset.Year == 2014]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 15       145220                  1. Principles of Simple Interest      True
# 17       157336                        10.  Bonds and Bond Pricing     True
# 21       315716         15 Mandamientos para ganar dinero en Bolsa     True
# ...         ...                                                ...      ...
# 3637     361620                              Wordpress Tutorial        True
# 3643     326948  Working Capital Management for CA / CFA / CPA ...     True
# 3644     221872       Working Capital Management for Entrepreneurs     True
# 3669     180384                               Yield Curve Dynamics     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
#
# ...

# %%
#What are courses published in the year 2014/2017/2020

Dataset[Dataset.Year == 2017]
# Out:
#       course_id                                       course_title  is_paid  \
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# 5       1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# ...         ...                                                ...      ...
# 3662    1115132            XML XQuery - Crash Course for Beginners     True
# 3663    1115126              XML XSLT - Crash Course for Beginners     True
# 3672    1031698                        You Can Play Jazz Saxophone     True
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
#What are courses published in the year 2014/2017/2020

Dataset[Dataset.Year == 2020]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject, Year, Month, Day]
# Index: []

# %%
#What are courses published in the month of March 2014/2017/2020

Dataset[Dataset.Month == 3]
# Out:
#       course_id                                       course_title  is_paid  \
# 5       1122832  #6 Piano Hand Coordination: Play Open 10 Balla...     True
# 6       1123184  #7 Piano Hand Coordination: Play Piano Runs in...     True
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 50       665042  8 Beautiful Ruby on Rails Apps in 30 Days & TD...     True
# ...         ...                                                ...      ...
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3654     440006  X theme for WordPress: Responsive web design w...     True
# 3669     180384                               Yield Curve Dynamics     True
# 3672    1031698                        You Can Play Jazz Saxophone     True
#
# ...

# %%
len(Dataset[Dataset.Month == 3])
# Out:
# 364

# %%
Dataset.sort_values('Month' , ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 205      368958  Advanced Graphic Design-Photoshop CC 2014 for ...     True
# 3100     379814  Sketching: How to Draw People, Hands, Eyes, Bu...     True
# 1980    1025026  Javascript - From Beginner to Pro-Build real w...     True
# 3071    1033944  Serverless Workflow Management with AWS Step F...    False
# 1964     572992  Investing: How to Fix Hidden Flaws Inside Your...     True
# ...         ...                                                ...      ...
# 2092    1079040  Leaps Options Trading System - Diagonal Leaps ...     True
# 181     1080584      Adobe Photoshop CC for Photographers Advanced     True
# 3263     380970  The Complete Bitcoin Course: Get .001 Bitcoin ...     True
# 1965     382824  Investment Banking Operations : Securities Tra...     True
# 2046     379722  jQuery Crash Course: Learn the Essentials of j...     True
#
# ...

# %%
#Month with highest publication

Dataset.value_counts('Month')
# Out:
# Month
# 5     376
# 3     364
# 4     357
# 6     353
# 2     339
# 11    298
# 1     293
# 10    286
# 7     278
# 8     254
# 12    245
# 9     239
# dtype: int64

# %%
#Days with highest publication

Dataset.value_counts('Day')
# Out:
# Day
# 29    150
# 13    147
# 12    141
# 19    135
# 23    132
# 1     132
# 17    131
# 27    129
# 3     129
# 24    128
# 8     127
# 28    126
# 22    125
# 2     122
# 18    122
# 9     121
# 26    118
# 6     117
# 21    116
# 16    115
# 20    112
# 14    112
# 7     111
# 10    110
# 15    108
# 11    107
# 25    106
# 5     102
# 4     101
# 30     95
# 31     55
# dtype: int64

# %%
#Year with highest publication

Dataset.value_counts('Year')
# Out:
# Year
# 2016    1206
# 2015    1014
# 2017     719
# 2014     491
# 2013     202
# 2012      45
# 2011       5
# dtype: int64

# %%
#What are the max nmber of subscribers for each level of courses.

Dataset.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
Dataset.groupby('level').max()
# Out:
#                     course_id  \
# level
# All Levels            1277924
# Beginner Level        1282064
# Expert Level          1275790
# Intermediate Level    1276182
#
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
# ...

# %%
Dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680    False
# 3681    False
# Length: 3682, dtype: bool
